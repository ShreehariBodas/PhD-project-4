# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import time
from scipy.optimize import fsolve, minimize
from scipy.integrate import quad
from numpy import linspace, meshgrid, arange, empty, concatenate, newaxis, shape
from collections import deque

# %%
# Import functions from other notebooks using %run
# %run estimation.ipynb
# %run MDP_core_allocation.ipynb

# %%
def simulate_window(jobs, jobs_in_system_ids, current_time, window_end_job_id, amdahl_pars, model_pars, pi_optimal, M):
    """
    Simulate queue for one window, continuing from existing jobs in system
    
    Parameters:
    - jobs: list of ALL Job objects (already created with arrival/service times, categories)
    - jobs_in_system_ids: list of job IDs currently in system (from previous window)
    - current_time: current simulation time
    - window_end_job_id: last job ID to arrive in this window
    - amdahl_pars: [p1, p2] for simulation (TRUE parameters)
    - model_pars: [lam, mu, cores, alpha]
    - pi_optimal: optimal policy matrix
    - M: max queue size for policy lookup
    
    Returns: events, n_jobs_after_events, core_alloc_after_events, jobs_in_system_ids, current_time
    """
    lam, mu, total_cores, alpha = model_pars
    p1, p2 = amdahl_pars
    
    events = []
    n_jobs_in_system_just_after_events = []
    core_allocation_just_after_events = []
    
    job_ids_in_system = jobs_in_system_ids.copy()
    
    # Find next job to arrive
    next_arrival_id = window_end_job_id + 1  # Start beyond window
    for jid in range(len(jobs)):
        if jobs[jid].arrival_time >= current_time and jid not in job_ids_in_system:
            next_arrival_id = jid
            break
    
    # Count jobs by category
    n_jobs_in_system = np.array([
        sum([1 for jid in job_ids_in_system if jobs[jid].category == 1]),
        sum([1 for jid in job_ids_in_system if jobs[jid].category == 2])
    ])
    
    while True:
        # Time until next arrival
        if next_arrival_id <= window_end_job_id:
            time_until_next_arrival = jobs[next_arrival_id].arrival_time - current_time
        else:
            time_until_next_arrival = math.inf
        
        # Time until next departure
        if len(job_ids_in_system) == 0:
            time_until_next_departure = math.inf
        else:
            # Core allocation from optimal policy
            n1, n2 = min(n_jobs_in_system[0], M), min(n_jobs_in_system[1], M)
            fraction_to_type1 = pi_optimal[n1, n2]
            current_core_allocation = np.array([fraction_to_type1 * total_cores, (1 - fraction_to_type1) * total_cores])
            
            # Cores per job and speed-up
            cores_per_job = np.array([
                current_core_allocation[0]/n_jobs_in_system[0] if n_jobs_in_system[0] > 0 else 0,
                current_core_allocation[1]/n_jobs_in_system[1] if n_jobs_in_system[1] > 0 else 0
            ])
            speed_up_values = np.array([speed_up(p1, cores_per_job[0]), speed_up(p2, cores_per_job[1])])
            
            # Time until departure
            expected_times = np.array([
                jobs[jid].residual_service_time / speed_up_values[int(jobs[jid].category) - 1]
                for jid in job_ids_in_system
            ])
            time_until_next_departure = np.min(expected_times)
        
        # Break if no more events
        if time_until_next_arrival == math.inf and time_until_next_departure == math.inf:
            break
        
        # Determine next event
        if time_until_next_arrival < time_until_next_departure:
            time_step = time_until_next_arrival
            event_type = 'arrival'
            event_job_id = next_arrival_id
        else:
            time_step = time_until_next_departure
            event_type = 'departure'
            event_job_id = job_ids_in_system[np.argmin(expected_times)]
        
        # Update residual service times
        if len(job_ids_in_system) > 0:
            for jid in job_ids_in_system:
                spd = speed_up_values[int(jobs[jid].category) - 1]
                jobs[jid].residual_service_time -= spd * time_step
                jobs[jid].history.append([spd, time_step])
        
        current_time += time_step
        
        # Process event
        if event_type == 'arrival':
            events.append([current_time, 'arrival', event_job_id])
            job_ids_in_system.append(event_job_id)
            n_jobs_in_system[int(jobs[event_job_id].category) - 1] += 1
            next_arrival_id += 1
        else:
            events.append([current_time, 'departure', event_job_id])
            job_ids_in_system.remove(event_job_id)
            n_jobs_in_system[int(jobs[event_job_id].category) - 1] -= 1
            jobs[event_job_id].departure_time = current_time
        
        # Record state
        n_jobs_in_system_just_after_events.append(n_jobs_in_system.copy())
        n1, n2 = min(n_jobs_in_system[0], M), min(n_jobs_in_system[1], M)
        fraction = pi_optimal[n1, n2]
        core_allocation_just_after_events.append(np.array([fraction * total_cores, (1-fraction) * total_cores]))
    
    return events, n_jobs_in_system_just_after_events, core_allocation_just_after_events, job_ids_in_system, current_time

# %%
def iterative_algorithm(true_pars, initial_estimates, jobs_per_window, total_windows):
    """
    Iteratively estimates p1, p2 and computes optimal policy over multiple windows
    Accumulates data across windows and properly continues jobs from previous windows
    """
    # Extract true parameters
    lam, mu, cores, p1_true, p2_true, alpha, M = true_pars
    model_pars = [lam, mu, cores, alpha]
    amdahl_pars_true = [p1_true, p2_true]
    
    # Initialize estimates
    p1_est, p2_est = initial_estimates
    estimates_history = [initial_estimates]
    policies_history = []
    
    # Preprocessing: Generate ALL jobs upfront
    total_jobs = jobs_per_window * total_windows
    arrival_times = generate_arrival_times(lam, total_jobs)
    service_times = generate_service_times(mu, total_jobs)
    job_categories = generate_job_categories(alpha, total_jobs)
    
    jobs = [Job() for i in range(total_jobs)]
    for i in range(total_jobs):
        jobs[i].identity = i
        jobs[i].arrival_time = arrival_times[i]
        jobs[i].service_time = service_times[i]
        jobs[i].residual_service_time = service_times[i]
        jobs[i].category = int(job_categories[i])
    
    # Accumulated data for estimation
    accumulated_events = []
    accumulated_n_jobs_in_system = []
    accumulated_core_allocation = []
    
    # Simulation state
    jobs_in_system_ids = []
    current_time = 0.0
    
    print("="*70)
    print("ITERATIVE ESTIMATION AND POLICY OPTIMIZATION ALGORITHM")
    print("="*70)
    print(f"True parameters: p1 = {p1_true:.4f}, p2 = {p2_true:.4f}")
    print(f"Initial estimates: p1 = {p1_est:.4f}, p2 = {p2_est:.4f}")
    print("Strategy: Accumulate ALL data + continue jobs across windows")
    print(f"Total jobs: {total_jobs} ({jobs_per_window} per window)")
    print("="*70)
    
    for window in range(total_windows):
        print(f"\n--- Window {window + 1}/{total_windows} ---")
        print(f"Current estimates: p1 = {p1_est:.4f}, p2 = {p2_est:.4f}")
        print(f"Jobs in system at start: {len(jobs_in_system_ids)}")
        
        # Step 1: Compute optimal policy
        est_pars = [lam, mu, cores, p1_est, p2_est, alpha, M]
        print("Computing optimal policy...")
        pi_optimal, V_optimal, Q_optimal = bellman_optimal_policy(est_pars)
        policies_history.append(pi_optimal)
        
        # Step 2: Simulate this window
        window_start_job_id = window * jobs_per_window
        window_end_job_id = (window + 1) * jobs_per_window - 1
        print(f"Simulating jobs {window_start_job_id} to {window_end_job_id}...")
        
        events, n_jobs, core_alloc, jobs_in_system_ids, current_time = simulate_window(
            jobs, jobs_in_system_ids, current_time, window_end_job_id,
            amdahl_pars_true, model_pars, pi_optimal, M
        )
        
        print(f"Simulated {len(events)} events, time = {current_time:.2f}")
        print(f"Jobs remaining in system: {len(jobs_in_system_ids)}")
        
        # Step 3: Accumulate data
        accumulated_events.extend(events)
        accumulated_n_jobs_in_system.extend(n_jobs)
        accumulated_core_allocation.extend(core_alloc)
        
        # Step 4: Estimate using ALL accumulated data
        print(f"Estimating from {len(accumulated_events)} total events...")
        estd_result = estimation(
            model_pars, jobs, jobs_in_system_ids,
            accumulated_events, accumulated_n_jobs_in_system, accumulated_core_allocation
        )
        p1_est, p2_est = estd_result.x
        p1_est = np.clip(p1_est, 0.001, 0.999)
        p2_est = np.clip(p2_est, 0.001, 0.999)
        estimates_history.append((p1_est, p2_est))
        
        error_p1 = abs(p1_est - p1_true)
        error_p2 = abs(p2_est - p2_true)
        print(f"Updated estimates: p1 = {p1_est:.4f}, p2 = {p2_est:.4f}")
        print(f"Errors: Δp1 = {error_p1:.4f}, Δp2 = {error_p2:.4f}")
    
    print("\n" + "="*70)
    print("ALGORITHM COMPLETED")
    print("="*70)
    
    return estimates_history, policies_history

# %%
# True system parameters
lam = 4 # Arrival rate
mu = 2.5 # Mean service time
cores = 30 # Total number of cores
p1_true = 0.3 # Bad jobs - lower parallelizability
p2_true = 0.8 # Good jobs - higher parallelizability
alpha = 0.35 # Fraction of type 1 jobs
M = 10 # Maximum queue size for MDP

true_pars = [lam, mu, cores, p1_true, p2_true, alpha, M]

# Algorithm parameters
initial_estimates = [0.5, 0.5] # Start with neutral beliefs
jobs_per_window = 100 # Jobs to simulate in each window
total_windows = 100 # Number of estimation-optimization iterations

# Run the iterative algorithm
estimates_history, policies_history = iterative_algorithm(
    true_pars, 
    initial_estimates, 
    jobs_per_window, 
    total_windows
)
# Out:
# ======================================================================
# ITERATIVE ESTIMATION AND POLICY OPTIMIZATION ALGORITHM
# ======================================================================
# True parameters: p1 = 0.3000, p2 = 0.8000
# Initial estimates: p1 = 0.5000, p2 = 0.5000
# Strategy: Accumulate ALL data + continue jobs across windows
# Total jobs: 10000 (100 per window)
# ======================================================================
#
# --- Window 1/100 ---
# Current estimates: p1 = 0.5000, p2 = 0.5000
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 0 to 99...
# Simulated 200 events, time = 22.21
# Jobs remaining in system: 0
# Estimating from 200 total events...
# Updated estimates: p1 = 0.4561, p2 = 0.7745
# Errors: Δp1 = 0.1561, Δp2 = 0.0255
#
# --- Window 2/100 ---
# Current estimates: p1 = 0.4561, p2 = 0.7745
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 100 to 199...
# Simulated 198 events, time = 50.29
# Jobs remaining in system: 0
# Estimating from 398 total events...
# Updated estimates: p1 = 0.3033, p2 = 0.7820
# Errors: Δp1 = 0.0033, Δp2 = 0.0180
#
# --- Window 3/100 ---
# Current estimates: p1 = 0.3033, p2 = 0.7820
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 200 to 299...
# Simulated 200 events, time = 76.58
# Jobs remaining in system: 0
# Estimating from 598 total events...
# Updated estimates: p1 = 0.2824, p2 = 0.7896
# Errors: Δp1 = 0.0176, Δp2 = 0.0104
#
# --- Window 4/100 ---
# Current estimates: p1 = 0.2824, p2 = 0.7896
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 300 to 399...
# Simulated 198 events, time = 101.28
# Jobs remaining in system: 0
# Estimating from 796 total events...
# Updated estimates: p1 = 0.2790, p2 = 0.8044
# Errors: Δp1 = 0.0210, Δp2 = 0.0044
#
# --- Window 5/100 ---
# Current estimates: p1 = 0.2790, p2 = 0.8044
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 400 to 499...
# Simulated 196 events, time = 129.14
# Jobs remaining in system: 0
# Estimating from 992 total events...
# Updated estimates: p1 = 0.2849, p2 = 0.7896
# Errors: Δp1 = 0.0151, Δp2 = 0.0104
#
# --- Window 6/100 ---
# Current estimates: p1 = 0.2849, p2 = 0.7896
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 500 to 599...
# Simulated 200 events, time = 155.91
# Jobs remaining in system: 0
# Estimating from 1192 total events...
# Updated estimates: p1 = 0.3075, p2 = 0.7903
# Errors: Δp1 = 0.0075, Δp2 = 0.0097
#
# --- Window 7/100 ---
# Current estimates: p1 = 0.3075, p2 = 0.7903
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 600 to 699...
# Simulated 198 events, time = 177.77
# Jobs remaining in system: 0
# Estimating from 1390 total events...
# Updated estimates: p1 = 0.3078, p2 = 0.8011
# Errors: Δp1 = 0.0078, Δp2 = 0.0011
#
# --- Window 8/100 ---
# Current estimates: p1 = 0.3078, p2 = 0.8011
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 700 to 799...
# Simulated 198 events, time = 200.44
# Jobs remaining in system: 0
# Estimating from 1588 total events...
# Updated estimates: p1 = 0.3103, p2 = 0.7949
# Errors: Δp1 = 0.0103, Δp2 = 0.0051
#
# --- Window 9/100 ---
# Current estimates: p1 = 0.3103, p2 = 0.7949
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 800 to 899...
# Simulated 196 events, time = 225.29
# Jobs remaining in system: 0
# Estimating from 1784 total events...
# Updated estimates: p1 = 0.3178, p2 = 0.7924
# Errors: Δp1 = 0.0178, Δp2 = 0.0076
#
# --- Window 10/100 ---
# Current estimates: p1 = 0.3178, p2 = 0.7924
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 900 to 999...
# Simulated 196 events, time = 249.88
# Jobs remaining in system: 0
# Estimating from 1980 total events...
# Updated estimates: p1 = 0.3011, p2 = 0.7914
# Errors: Δp1 = 0.0011, Δp2 = 0.0086
#
# --- Window 11/100 ---
# Current estimates: p1 = 0.3011, p2 = 0.7914
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 1000 to 1099...
# Simulated 200 events, time = 273.19
# Jobs remaining in system: 0
# Estimating from 2180 total events...
# Updated estimates: p1 = 0.3037, p2 = 0.7907
# Errors: Δp1 = 0.0037, Δp2 = 0.0093
#
# --- Window 12/100 ---
# Current estimates: p1 = 0.3037, p2 = 0.7907
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 1100 to 1199...
# Simulated 200 events, time = 295.14
# Jobs remaining in system: 0
# Estimating from 2380 total events...
# Updated estimates: p1 = 0.3063, p2 = 0.7932
# Errors: Δp1 = 0.0063, Δp2 = 0.0068
#
# --- Window 13/100 ---
# Current estimates: p1 = 0.3063, p2 = 0.7932
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 1200 to 1299...
# Simulated 198 events, time = 316.92
# Jobs remaining in system: 0
# Estimating from 2578 total events...
# Updated estimates: p1 = 0.3086, p2 = 0.7980
# Errors: Δp1 = 0.0086, Δp2 = 0.0020
#
# --- Window 14/100 ---
# Current estimates: p1 = 0.3086, p2 = 0.7980
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 1300 to 1399...
# Simulated 200 events, time = 348.49
# Jobs remaining in system: 0
# Estimating from 2778 total events...
# Updated estimates: p1 = 0.3077, p2 = 0.8003
# Errors: Δp1 = 0.0077, Δp2 = 0.0003
#
# --- Window 15/100 ---
# Current estimates: p1 = 0.3077, p2 = 0.8003
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 1400 to 1499...
# Simulated 200 events, time = 374.28
# Jobs remaining in system: 0
# Estimating from 2978 total events...
# Updated estimates: p1 = 0.3113, p2 = 0.7985
# Errors: Δp1 = 0.0113, Δp2 = 0.0015
#
# --- Window 16/100 ---
# Current estimates: p1 = 0.3113, p2 = 0.7985
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 1500 to 1599...
# Simulated 194 events, time = 399.32
# Jobs remaining in system: 0
# Estimating from 3172 total events...
# Updated estimates: p1 = 0.3155, p2 = 0.7973
# Errors: Δp1 = 0.0155, Δp2 = 0.0027
#
# --- Window 17/100 ---
# Current estimates: p1 = 0.3155, p2 = 0.7973
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 1600 to 1699...
# Simulated 200 events, time = 421.84
# Jobs remaining in system: 0
# Estimating from 3372 total events...
# Updated estimates: p1 = 0.3167, p2 = 0.7974
# Errors: Δp1 = 0.0167, Δp2 = 0.0026
#
# --- Window 18/100 ---
# Current estimates: p1 = 0.3167, p2 = 0.7974
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 1700 to 1799...
# Simulated 196 events, time = 449.43
# Jobs remaining in system: 0
# Estimating from 3568 total events...
# Updated estimates: p1 = 0.3173, p2 = 0.7963
# Errors: Δp1 = 0.0173, Δp2 = 0.0037
#
# --- Window 19/100 ---
# Current estimates: p1 = 0.3173, p2 = 0.7963
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 1800 to 1899...
# Simulated 198 events, time = 471.30
# Jobs remaining in system: 0
# Estimating from 3766 total events...
# Updated estimates: p1 = 0.3143, p2 = 0.7959
# Errors: Δp1 = 0.0143, Δp2 = 0.0041
#
# --- Window 20/100 ---
# Current estimates: p1 = 0.3143, p2 = 0.7959
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 1900 to 1999...
# Simulated 196 events, time = 496.13
# Jobs remaining in system: 0
# Estimating from 3962 total events...
# Updated estimates: p1 = 0.3175, p2 = 0.7927
# Errors: Δp1 = 0.0175, Δp2 = 0.0073
#
# --- Window 21/100 ---
# Current estimates: p1 = 0.3175, p2 = 0.7927
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 2000 to 2099...
# Simulated 198 events, time = 522.67
# Jobs remaining in system: 0
# Estimating from 4160 total events...
# Updated estimates: p1 = 0.3184, p2 = 0.7914
# Errors: Δp1 = 0.0184, Δp2 = 0.0086
#
# --- Window 22/100 ---
# Current estimates: p1 = 0.3184, p2 = 0.7914
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 2100 to 2199...
# Simulated 198 events, time = 547.44
# Jobs remaining in system: 0
# Estimating from 4358 total events...
# Updated estimates: p1 = 0.3155, p2 = 0.7944
# Errors: Δp1 = 0.0155, Δp2 = 0.0056
#
# --- Window 23/100 ---
# Current estimates: p1 = 0.3155, p2 = 0.7944
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 2200 to 2299...
# Simulated 200 events, time = 570.46
# Jobs remaining in system: 0
# Estimating from 4558 total events...
# Updated estimates: p1 = 0.3112, p2 = 0.7936
# Errors: Δp1 = 0.0112, Δp2 = 0.0064
#
# --- Window 24/100 ---
# Current estimates: p1 = 0.3112, p2 = 0.7936
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 2300 to 2399...
# Simulated 200 events, time = 596.46
# Jobs remaining in system: 0
# Estimating from 4758 total events...
# Updated estimates: p1 = 0.3097, p2 = 0.7951
# Errors: Δp1 = 0.0097, Δp2 = 0.0049
#
# --- Window 25/100 ---
# Current estimates: p1 = 0.3097, p2 = 0.7951
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 2400 to 2499...
# Simulated 200 events, time = 622.32
# Jobs remaining in system: 0
# Estimating from 4958 total events...
# Updated estimates: p1 = 0.3085, p2 = 0.7939
# Errors: Δp1 = 0.0085, Δp2 = 0.0061
#
# --- Window 26/100 ---
# Current estimates: p1 = 0.3085, p2 = 0.7939
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 2500 to 2599...
# Simulated 200 events, time = 646.41
# Jobs remaining in system: 0
# Estimating from 5158 total events...
# Updated estimates: p1 = 0.3064, p2 = 0.7975
# Errors: Δp1 = 0.0064, Δp2 = 0.0025
#
# --- Window 27/100 ---
# Current estimates: p1 = 0.3064, p2 = 0.7975
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 2600 to 2699...
# Simulated 200 events, time = 666.92
# Jobs remaining in system: 0
# Estimating from 5358 total events...
# Updated estimates: p1 = 0.3090, p2 = 0.8002
# Errors: Δp1 = 0.0090, Δp2 = 0.0002
#
# --- Window 28/100 ---
# Current estimates: p1 = 0.3090, p2 = 0.8002
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 2700 to 2799...
# Simulated 198 events, time = 698.35
# Jobs remaining in system: 0
# Estimating from 5556 total events...
# Updated estimates: p1 = 0.3103, p2 = 0.8005
# Errors: Δp1 = 0.0103, Δp2 = 0.0005
#
# --- Window 29/100 ---
# Current estimates: p1 = 0.3103, p2 = 0.8005
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 2800 to 2899...
# Simulated 196 events, time = 725.96
# Jobs remaining in system: 0
# Estimating from 5752 total events...
# Updated estimates: p1 = 0.3120, p2 = 0.8011
# Errors: Δp1 = 0.0120, Δp2 = 0.0011
#
# --- Window 30/100 ---
# Current estimates: p1 = 0.3120, p2 = 0.8011
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 2900 to 2999...
# Simulated 200 events, time = 751.39
# Jobs remaining in system: 0
# Estimating from 5952 total events...
# Updated estimates: p1 = 0.3113, p2 = 0.8004
# Errors: Δp1 = 0.0113, Δp2 = 0.0004
#
# --- Window 31/100 ---
# Current estimates: p1 = 0.3113, p2 = 0.8004
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 3000 to 3099...
# Simulated 196 events, time = 777.36
# Jobs remaining in system: 0
# Estimating from 6148 total events...
# Updated estimates: p1 = 0.3113, p2 = 0.8022
# Errors: Δp1 = 0.0113, Δp2 = 0.0022
#
# --- Window 32/100 ---
# Current estimates: p1 = 0.3113, p2 = 0.8022
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 3100 to 3199...
# Simulated 200 events, time = 806.74
# Jobs remaining in system: 0
# Estimating from 6348 total events...
# Updated estimates: p1 = 0.3159, p2 = 0.8023
# Errors: Δp1 = 0.0159, Δp2 = 0.0023
#
# --- Window 33/100 ---
# Current estimates: p1 = 0.3159, p2 = 0.8023
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 3200 to 3299...
# Simulated 198 events, time = 830.78
# Jobs remaining in system: 0
# Estimating from 6546 total events...
# Updated estimates: p1 = 0.3156, p2 = 0.8012
# Errors: Δp1 = 0.0156, Δp2 = 0.0012
#
# --- Window 34/100 ---
# Current estimates: p1 = 0.3156, p2 = 0.8012
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 3300 to 3399...
# Simulated 200 events, time = 853.76
# Jobs remaining in system: 0
# Estimating from 6746 total events...
# Updated estimates: p1 = 0.3169, p2 = 0.8027
# Errors: Δp1 = 0.0169, Δp2 = 0.0027
#
# --- Window 35/100 ---
# Current estimates: p1 = 0.3169, p2 = 0.8027
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 3400 to 3499...
# Simulated 198 events, time = 879.63
# Jobs remaining in system: 0
# Estimating from 6944 total events...
# Updated estimates: p1 = 0.3148, p2 = 0.8043
# Errors: Δp1 = 0.0148, Δp2 = 0.0043
#
# --- Window 36/100 ---
# Current estimates: p1 = 0.3148, p2 = 0.8043
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 3500 to 3599...
# Simulated 200 events, time = 904.41
# Jobs remaining in system: 0
# Estimating from 7144 total events...
# Updated estimates: p1 = 0.3116, p2 = 0.8045
# Errors: Δp1 = 0.0116, Δp2 = 0.0045
#
# --- Window 37/100 ---
# Current estimates: p1 = 0.3116, p2 = 0.8045
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 3600 to 3699...
# Simulated 190 events, time = 927.20
# Jobs remaining in system: 0
# Estimating from 7334 total events...
# Updated estimates: p1 = 0.3027, p2 = 0.8048
# Errors: Δp1 = 0.0027, Δp2 = 0.0048
#
# --- Window 38/100 ---
# Current estimates: p1 = 0.3027, p2 = 0.8048
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 3700 to 3799...
# Simulated 200 events, time = 954.72
# Jobs remaining in system: 0
# Estimating from 7534 total events...
# Updated estimates: p1 = 0.3051, p2 = 0.8043
# Errors: Δp1 = 0.0051, Δp2 = 0.0043
#
# --- Window 39/100 ---
# Current estimates: p1 = 0.3051, p2 = 0.8043
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 3800 to 3899...
# Simulated 196 events, time = 975.74
# Jobs remaining in system: 0
# Estimating from 7730 total events...
# Updated estimates: p1 = 0.3046, p2 = 0.8055
# Errors: Δp1 = 0.0046, Δp2 = 0.0055
#
# --- Window 40/100 ---
# Current estimates: p1 = 0.3046, p2 = 0.8055
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 3900 to 3999...
# Simulated 198 events, time = 997.41
# Jobs remaining in system: 0
# Estimating from 7928 total events...
# Updated estimates: p1 = 0.3048, p2 = 0.8059
# Errors: Δp1 = 0.0048, Δp2 = 0.0059
#
# --- Window 41/100 ---
# Current estimates: p1 = 0.3048, p2 = 0.8059
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 4000 to 4099...
# Simulated 198 events, time = 1024.74
# Jobs remaining in system: 0
# Estimating from 8126 total events...
# Updated estimates: p1 = 0.3028, p2 = 0.8086
# Errors: Δp1 = 0.0028, Δp2 = 0.0086
#
# --- Window 42/100 ---
# Current estimates: p1 = 0.3028, p2 = 0.8086
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 4100 to 4199...
# Simulated 194 events, time = 1058.08
# Jobs remaining in system: 0
# Estimating from 8320 total events...
# Updated estimates: p1 = 0.3022, p2 = 0.8071
# Errors: Δp1 = 0.0022, Δp2 = 0.0071
#
# --- Window 43/100 ---
# Current estimates: p1 = 0.3022, p2 = 0.8071
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 4200 to 4299...
# Simulated 198 events, time = 1089.42
# Jobs remaining in system: 0
# Estimating from 8518 total events...
# Updated estimates: p1 = 0.3017, p2 = 0.8061
# Errors: Δp1 = 0.0017, Δp2 = 0.0061
#
# --- Window 44/100 ---
# Current estimates: p1 = 0.3017, p2 = 0.8061
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 4300 to 4399...
# Simulated 184 events, time = 1116.98
# Jobs remaining in system: 0
# Estimating from 8702 total events...
# Updated estimates: p1 = 0.3017, p2 = 0.8046
# Errors: Δp1 = 0.0017, Δp2 = 0.0046
#
# --- Window 45/100 ---
# Current estimates: p1 = 0.3017, p2 = 0.8046
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 4400 to 4499...
# Simulated 196 events, time = 1141.99
# Jobs remaining in system: 0
# Estimating from 8898 total events...
# Updated estimates: p1 = 0.3020, p2 = 0.8042
# Errors: Δp1 = 0.0020, Δp2 = 0.0042
#
# --- Window 46/100 ---
# Current estimates: p1 = 0.3020, p2 = 0.8042
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 4500 to 4599...
# Simulated 196 events, time = 1168.43
# Jobs remaining in system: 0
# Estimating from 9094 total events...
# Updated estimates: p1 = 0.3037, p2 = 0.8044
# Errors: Δp1 = 0.0037, Δp2 = 0.0044
#
# --- Window 47/100 ---
# Current estimates: p1 = 0.3037, p2 = 0.8044
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 4600 to 4699...
# Simulated 200 events, time = 1191.49
# Jobs remaining in system: 0
# Estimating from 9294 total events...
# Updated estimates: p1 = 0.3061, p2 = 0.8059
# Errors: Δp1 = 0.0061, Δp2 = 0.0059
#
# --- Window 48/100 ---
# Current estimates: p1 = 0.3061, p2 = 0.8059
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 4700 to 4799...
# Simulated 198 events, time = 1219.60
# Jobs remaining in system: 0
# Estimating from 9492 total events...
# Updated estimates: p1 = 0.3028, p2 = 0.8049
# Errors: Δp1 = 0.0028, Δp2 = 0.0049
#
# --- Window 49/100 ---
# Current estimates: p1 = 0.3028, p2 = 0.8049
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 4800 to 4899...
# Simulated 200 events, time = 1245.88
# Jobs remaining in system: 0
# Estimating from 9692 total events...
# Updated estimates: p1 = 0.2977, p2 = 0.8043
# Errors: Δp1 = 0.0023, Δp2 = 0.0043
#
# --- Window 50/100 ---
# Current estimates: p1 = 0.2977, p2 = 0.8043
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 4900 to 4999...
# Simulated 196 events, time = 1266.77
# Jobs remaining in system: 0
# Estimating from 9888 total events...
# Updated estimates: p1 = 0.2988, p2 = 0.8030
# Errors: Δp1 = 0.0012, Δp2 = 0.0030
#
# --- Window 51/100 ---
# Current estimates: p1 = 0.2988, p2 = 0.8030
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 5000 to 5099...
# Simulated 200 events, time = 1292.13
# Jobs remaining in system: 0
# Estimating from 10088 total events...
# Updated estimates: p1 = 0.3001, p2 = 0.8031
# Errors: Δp1 = 0.0001, Δp2 = 0.0031
#
# --- Window 52/100 ---
# Current estimates: p1 = 0.3001, p2 = 0.8031
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 5100 to 5199...
# Simulated 194 events, time = 1320.29
# Jobs remaining in system: 0
# Estimating from 10282 total events...
# Updated estimates: p1 = 0.2991, p2 = 0.8037
# Errors: Δp1 = 0.0009, Δp2 = 0.0037
#
# --- Window 53/100 ---
# Current estimates: p1 = 0.2991, p2 = 0.8037
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 5200 to 5299...
# Simulated 200 events, time = 1342.75
# Jobs remaining in system: 0
# Estimating from 10482 total events...
# Updated estimates: p1 = 0.2969, p2 = 0.8037
# Errors: Δp1 = 0.0031, Δp2 = 0.0037
#
# --- Window 54/100 ---
# Current estimates: p1 = 0.2969, p2 = 0.8037
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 5300 to 5399...
# Simulated 194 events, time = 1362.18
# Jobs remaining in system: 0
# Estimating from 10676 total events...
# Updated estimates: p1 = 0.2989, p2 = 0.8043
# Errors: Δp1 = 0.0011, Δp2 = 0.0043
#
# --- Window 55/100 ---
# Current estimates: p1 = 0.2989, p2 = 0.8043
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 5400 to 5499...
# Simulated 200 events, time = 1385.74
# Jobs remaining in system: 0
# Estimating from 10876 total events...
# Updated estimates: p1 = 0.2981, p2 = 0.8043
# Errors: Δp1 = 0.0019, Δp2 = 0.0043
#
# --- Window 56/100 ---
# Current estimates: p1 = 0.2981, p2 = 0.8043
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 5500 to 5599...
# Simulated 198 events, time = 1412.77
# Jobs remaining in system: 0
# Estimating from 11074 total events...
# Updated estimates: p1 = 0.2988, p2 = 0.8043
# Errors: Δp1 = 0.0012, Δp2 = 0.0043
#
# --- Window 57/100 ---
# Current estimates: p1 = 0.2988, p2 = 0.8043
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 5600 to 5699...
# Simulated 196 events, time = 1436.40
# Jobs remaining in system: 0
# Estimating from 11270 total events...
# Updated estimates: p1 = 0.2975, p2 = 0.8057
# Errors: Δp1 = 0.0025, Δp2 = 0.0057
#
# --- Window 58/100 ---
# Current estimates: p1 = 0.2975, p2 = 0.8057
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 5700 to 5799...
# Simulated 200 events, time = 1459.01
# Jobs remaining in system: 0
# Estimating from 11470 total events...
# Updated estimates: p1 = 0.2974, p2 = 0.8067
# Errors: Δp1 = 0.0026, Δp2 = 0.0067
#
# --- Window 59/100 ---
# Current estimates: p1 = 0.2974, p2 = 0.8067
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 5800 to 5899...
# Simulated 198 events, time = 1483.58
# Jobs remaining in system: 0
# Estimating from 11668 total events...
# Updated estimates: p1 = 0.2974, p2 = 0.8063
# Errors: Δp1 = 0.0026, Δp2 = 0.0063
#
# --- Window 60/100 ---
# Current estimates: p1 = 0.2974, p2 = 0.8063
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 5900 to 5999...
# Simulated 200 events, time = 1507.66
# Jobs remaining in system: 0
# Estimating from 11868 total events...
# Updated estimates: p1 = 0.2964, p2 = 0.8063
# Errors: Δp1 = 0.0036, Δp2 = 0.0063
#
# --- Window 61/100 ---
# Current estimates: p1 = 0.2964, p2 = 0.8063
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 6000 to 6099...
# Simulated 200 events, time = 1530.63
# Jobs remaining in system: 0
# Estimating from 12068 total events...
# Updated estimates: p1 = 0.2955, p2 = 0.8060
# Errors: Δp1 = 0.0045, Δp2 = 0.0060
#
# --- Window 62/100 ---
# Current estimates: p1 = 0.2955, p2 = 0.8060
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 6100 to 6199...
# Simulated 200 events, time = 1559.52
# Jobs remaining in system: 0
# Estimating from 12268 total events...
# Updated estimates: p1 = 0.2961, p2 = 0.8051
# Errors: Δp1 = 0.0039, Δp2 = 0.0051
#
# --- Window 63/100 ---
# Current estimates: p1 = 0.2961, p2 = 0.8051
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 6200 to 6299...
# Simulated 192 events, time = 1588.19
# Jobs remaining in system: 0
# Estimating from 12460 total events...
# Updated estimates: p1 = 0.2957, p2 = 0.8041
# Errors: Δp1 = 0.0043, Δp2 = 0.0041
#
# --- Window 64/100 ---
# Current estimates: p1 = 0.2957, p2 = 0.8041
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 6300 to 6399...
# Simulated 200 events, time = 1616.01
# Jobs remaining in system: 0
# Estimating from 12660 total events...
# Updated estimates: p1 = 0.2965, p2 = 0.8049
# Errors: Δp1 = 0.0035, Δp2 = 0.0049
#
# --- Window 65/100 ---
# Current estimates: p1 = 0.2965, p2 = 0.8049
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 6400 to 6499...
# Simulated 200 events, time = 1645.26
# Jobs remaining in system: 0
# Estimating from 12860 total events...
# Updated estimates: p1 = 0.2995, p2 = 0.8036
# Errors: Δp1 = 0.0005, Δp2 = 0.0036
#
# --- Window 66/100 ---
# Current estimates: p1 = 0.2995, p2 = 0.8036
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 6500 to 6599...
# Simulated 196 events, time = 1671.55
# Jobs remaining in system: 0
# Estimating from 13056 total events...
# Updated estimates: p1 = 0.2986, p2 = 0.8038
# Errors: Δp1 = 0.0014, Δp2 = 0.0038
#
# --- Window 67/100 ---
# Current estimates: p1 = 0.2986, p2 = 0.8038
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 6600 to 6699...
# Simulated 196 events, time = 1698.94
# Jobs remaining in system: 0
# Estimating from 13252 total events...
# Updated estimates: p1 = 0.2946, p2 = 0.8026
# Errors: Δp1 = 0.0054, Δp2 = 0.0026
#
# --- Window 68/100 ---
# Current estimates: p1 = 0.2946, p2 = 0.8026
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 6700 to 6799...
# Simulated 192 events, time = 1725.07
# Jobs remaining in system: 0
# Estimating from 13444 total events...
# Updated estimates: p1 = 0.2947, p2 = 0.8020
# Errors: Δp1 = 0.0053, Δp2 = 0.0020
#
# --- Window 69/100 ---
# Current estimates: p1 = 0.2947, p2 = 0.8020
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 6800 to 6899...
# Simulated 188 events, time = 1746.40
# Jobs remaining in system: 0
# Estimating from 13632 total events...
# Updated estimates: p1 = 0.2956, p2 = 0.8029
# Errors: Δp1 = 0.0044, Δp2 = 0.0029
#
# --- Window 70/100 ---
# Current estimates: p1 = 0.2956, p2 = 0.8029
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 6900 to 6999...
# Simulated 200 events, time = 1773.43
# Jobs remaining in system: 0
# Estimating from 13832 total events...
# Updated estimates: p1 = 0.2976, p2 = 0.8023
# Errors: Δp1 = 0.0024, Δp2 = 0.0023
#
# --- Window 71/100 ---
# Current estimates: p1 = 0.2976, p2 = 0.8023
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 7000 to 7099...
# Simulated 188 events, time = 1796.20
# Jobs remaining in system: 0
# Estimating from 14020 total events...
# Updated estimates: p1 = 0.2972, p2 = 0.8022
# Errors: Δp1 = 0.0028, Δp2 = 0.0022
#
# --- Window 72/100 ---
# Current estimates: p1 = 0.2972, p2 = 0.8022
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 7100 to 7199...
# Simulated 196 events, time = 1819.93
# Jobs remaining in system: 0
# Estimating from 14216 total events...
# Updated estimates: p1 = 0.2980, p2 = 0.8017
# Errors: Δp1 = 0.0020, Δp2 = 0.0017
#
# --- Window 73/100 ---
# Current estimates: p1 = 0.2980, p2 = 0.8017
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 7200 to 7299...
# Simulated 200 events, time = 1846.69
# Jobs remaining in system: 0
# Estimating from 14416 total events...
# Updated estimates: p1 = 0.2970, p2 = 0.8025
# Errors: Δp1 = 0.0030, Δp2 = 0.0025
#
# --- Window 74/100 ---
# Current estimates: p1 = 0.2970, p2 = 0.8025
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 7300 to 7399...
# Simulated 200 events, time = 1871.52
# Jobs remaining in system: 0
# Estimating from 14616 total events...
# Updated estimates: p1 = 0.2977, p2 = 0.8019
# Errors: Δp1 = 0.0023, Δp2 = 0.0019
#
# --- Window 75/100 ---
# Current estimates: p1 = 0.2977, p2 = 0.8019
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 7400 to 7499...
# Simulated 200 events, time = 1899.03
# Jobs remaining in system: 0
# Estimating from 14816 total events...
# Updated estimates: p1 = 0.2970, p2 = 0.8023
# Errors: Δp1 = 0.0030, Δp2 = 0.0023
#
# --- Window 76/100 ---
# Current estimates: p1 = 0.2970, p2 = 0.8023
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 7500 to 7599...
# Simulated 194 events, time = 1923.00
# Jobs remaining in system: 0
# Estimating from 15010 total events...
# Updated estimates: p1 = 0.2967, p2 = 0.8026
# Errors: Δp1 = 0.0033, Δp2 = 0.0026
#
# --- Window 77/100 ---
# Current estimates: p1 = 0.2967, p2 = 0.8026
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 7600 to 7699...
# Simulated 198 events, time = 1952.48
# Jobs remaining in system: 0
# Estimating from 15208 total events...
# Updated estimates: p1 = 0.2967, p2 = 0.8028
# Errors: Δp1 = 0.0033, Δp2 = 0.0028
#
# --- Window 78/100 ---
# Current estimates: p1 = 0.2967, p2 = 0.8028
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 7700 to 7799...
# Simulated 198 events, time = 1975.08
# Jobs remaining in system: 0
# Estimating from 15406 total events...
# Updated estimates: p1 = 0.2973, p2 = 0.8036
# Errors: Δp1 = 0.0027, Δp2 = 0.0036
#
# --- Window 79/100 ---
# Current estimates: p1 = 0.2973, p2 = 0.8036
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 7800 to 7899...
# Simulated 198 events, time = 1999.30
# Jobs remaining in system: 0
# Estimating from 15604 total events...
# Updated estimates: p1 = 0.2950, p2 = 0.8034
# Errors: Δp1 = 0.0050, Δp2 = 0.0034
#
# --- Window 80/100 ---
# Current estimates: p1 = 0.2950, p2 = 0.8034
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 7900 to 7999...
# Simulated 194 events, time = 2022.89
# Jobs remaining in system: 0
# Estimating from 15798 total events...
# Updated estimates: p1 = 0.2926, p2 = 0.8028
# Errors: Δp1 = 0.0074, Δp2 = 0.0028
#
# --- Window 81/100 ---
# Current estimates: p1 = 0.2926, p2 = 0.8028
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 8000 to 8099...
# Simulated 200 events, time = 2053.61
# Jobs remaining in system: 0
# Estimating from 15998 total events...
# Updated estimates: p1 = 0.2932, p2 = 0.8023
# Errors: Δp1 = 0.0068, Δp2 = 0.0023
#
# --- Window 82/100 ---
# Current estimates: p1 = 0.2932, p2 = 0.8023
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 8100 to 8199...
# Simulated 198 events, time = 2079.26
# Jobs remaining in system: 0
# Estimating from 16196 total events...
# Updated estimates: p1 = 0.2932, p2 = 0.8022
# Errors: Δp1 = 0.0068, Δp2 = 0.0022
#
# --- Window 83/100 ---
# Current estimates: p1 = 0.2932, p2 = 0.8022
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 8200 to 8299...
# Simulated 198 events, time = 2103.82
# Jobs remaining in system: 0
# Estimating from 16394 total events...
# Updated estimates: p1 = 0.2922, p2 = 0.8021
# Errors: Δp1 = 0.0078, Δp2 = 0.0021
#
# --- Window 84/100 ---
# Current estimates: p1 = 0.2922, p2 = 0.8021
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 8300 to 8399...
# Simulated 198 events, time = 2130.81
# Jobs remaining in system: 0
# Estimating from 16592 total events...
# Updated estimates: p1 = 0.2922, p2 = 0.8017
# Errors: Δp1 = 0.0078, Δp2 = 0.0017
#
# --- Window 85/100 ---
# Current estimates: p1 = 0.2922, p2 = 0.8017
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 8400 to 8499...
# Simulated 196 events, time = 2156.37
# Jobs remaining in system: 0
# Estimating from 16788 total events...
# Updated estimates: p1 = 0.2927, p2 = 0.8011
# Errors: Δp1 = 0.0073, Δp2 = 0.0011
#
# --- Window 86/100 ---
# Current estimates: p1 = 0.2927, p2 = 0.8011
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 8500 to 8599...
# Simulated 198 events, time = 2175.98
# Jobs remaining in system: 0
# Estimating from 16986 total events...
# Updated estimates: p1 = 0.2926, p2 = 0.8012
# Errors: Δp1 = 0.0074, Δp2 = 0.0012
#
# --- Window 87/100 ---
# Current estimates: p1 = 0.2926, p2 = 0.8012
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 8600 to 8699...
# Simulated 200 events, time = 2198.95
# Jobs remaining in system: 0
# Estimating from 17186 total events...
# Updated estimates: p1 = 0.2934, p2 = 0.8017
# Errors: Δp1 = 0.0066, Δp2 = 0.0017
#
# --- Window 88/100 ---
# Current estimates: p1 = 0.2934, p2 = 0.8017
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 8700 to 8799...
# Simulated 200 events, time = 2227.90
# Jobs remaining in system: 0
# Estimating from 17386 total events...
# Updated estimates: p1 = 0.2945, p2 = 0.8014
# Errors: Δp1 = 0.0055, Δp2 = 0.0014
#
# --- Window 89/100 ---
# Current estimates: p1 = 0.2945, p2 = 0.8014
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 8800 to 8899...
# Simulated 200 events, time = 2251.58
# Jobs remaining in system: 0
# Estimating from 17586 total events...
# Updated estimates: p1 = 0.2939, p2 = 0.8008
# Errors: Δp1 = 0.0061, Δp2 = 0.0008
#
# --- Window 90/100 ---
# Current estimates: p1 = 0.2939, p2 = 0.8008
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 8900 to 8999...
# Simulated 198 events, time = 2274.10
# Jobs remaining in system: 0
# Estimating from 17784 total events...
# Updated estimates: p1 = 0.2935, p2 = 0.8009
# Errors: Δp1 = 0.0065, Δp2 = 0.0009
#
# --- Window 91/100 ---
# Current estimates: p1 = 0.2935, p2 = 0.8009
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 9000 to 9099...
# Simulated 198 events, time = 2298.09
# Jobs remaining in system: 0
# Estimating from 17982 total events...
# Updated estimates: p1 = 0.2939, p2 = 0.8012
# Errors: Δp1 = 0.0061, Δp2 = 0.0012
#
# --- Window 92/100 ---
# Current estimates: p1 = 0.2939, p2 = 0.8012
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 9100 to 9199...
# Simulated 192 events, time = 2322.28
# Jobs remaining in system: 0
# Estimating from 18174 total events...
# Updated estimates: p1 = 0.2932, p2 = 0.8015
# Errors: Δp1 = 0.0068, Δp2 = 0.0015
#
# --- Window 93/100 ---
# Current estimates: p1 = 0.2932, p2 = 0.8015
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 9200 to 9299...
# Simulated 196 events, time = 2350.52
# Jobs remaining in system: 0
# Estimating from 18370 total events...
# Updated estimates: p1 = 0.2929, p2 = 0.8010
# Errors: Δp1 = 0.0071, Δp2 = 0.0010
#
# --- Window 94/100 ---
# Current estimates: p1 = 0.2929, p2 = 0.8010
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 9300 to 9399...
# Simulated 196 events, time = 2379.24
# Jobs remaining in system: 0
# Estimating from 18566 total events...
# Updated estimates: p1 = 0.2925, p2 = 0.8009
# Errors: Δp1 = 0.0075, Δp2 = 0.0009
#
# --- Window 95/100 ---
# Current estimates: p1 = 0.2925, p2 = 0.8009
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 9400 to 9499...
# Simulated 188 events, time = 2405.19
# Jobs remaining in system: 0
# Estimating from 18754 total events...
# Updated estimates: p1 = 0.2926, p2 = 0.8008
# Errors: Δp1 = 0.0074, Δp2 = 0.0008
#
# --- Window 96/100 ---
# Current estimates: p1 = 0.2926, p2 = 0.8008
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 9500 to 9599...
# Simulated 200 events, time = 2428.59
# Jobs remaining in system: 0
# Estimating from 18954 total events...
# Updated estimates: p1 = 0.2931, p2 = 0.8012
# Errors: Δp1 = 0.0069, Δp2 = 0.0012
#
# --- Window 97/100 ---
# Current estimates: p1 = 0.2931, p2 = 0.8012
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 9600 to 9699...
# Simulated 200 events, time = 2456.30
# Jobs remaining in system: 0
# Estimating from 19154 total events...
# Updated estimates: p1 = 0.2936, p2 = 0.8007
# Errors: Δp1 = 0.0064, Δp2 = 0.0007
#
# --- Window 98/100 ---
# Current estimates: p1 = 0.2936, p2 = 0.8007
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 9700 to 9799...
# Simulated 200 events, time = 2482.59
# Jobs remaining in system: 0
# Estimating from 19354 total events...
# Updated estimates: p1 = 0.2948, p2 = 0.8006
# Errors: Δp1 = 0.0052, Δp2 = 0.0006
#
# --- Window 99/100 ---
# Current estimates: p1 = 0.2948, p2 = 0.8006
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 9800 to 9899...
# Simulated 188 events, time = 2504.04
# Jobs remaining in system: 0
# Estimating from 19542 total events...
# Updated estimates: p1 = 0.2947, p2 = 0.8002
# Errors: Δp1 = 0.0053, Δp2 = 0.0002
#
# --- Window 100/100 ---
# Current estimates: p1 = 0.2947, p2 = 0.8002
# Jobs in system at start: 0
# Computing optimal policy...
# Simulating jobs 9900 to 9999...
# Simulated 196 events, time = 2531.94
# Jobs remaining in system: 0
# Estimating from 19738 total events...
# Updated estimates: p1 = 0.2932, p2 = 0.8008
# Errors: Δp1 = 0.0068, Δp2 = 0.0008
#
# ======================================================================
# ALGORITHM COMPLETED
# ======================================================================

# %%
# Visualize convergence of estimates
p1_estimates = [est[0] for est in estimates_history]
p2_estimates = [est[1] for est in estimates_history]

# Enable LaTeX rendering
plt.rcParams['text.usetex'] = True
plt.rcParams['font.family'] = 'serif'

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

# Plot p_1 estimates
ax1.plot(range(len(p1_estimates)), p1_estimates, 'o-', linewidth=2, markersize=4)
ax1.axhline(y=p1_true, color='r', linestyle='--', linewidth=2)
ax1.set_xlabel(r'$k$', fontsize=20)
ax1.set_ylabel(r'$\widehat{p}_{1,k}$', fontsize=20)
ax1.grid(True, alpha=0.3)

# Plot p_2 estimates
ax2.plot(range(len(p2_estimates)), p2_estimates, 'o-', linewidth=2, markersize=4, color='green')
ax2.axhline(y=p2_true, color='r', linestyle='--', linewidth=2)
ax2.set_xlabel(r'$k$', fontsize=20)
ax2.set_ylabel(r'$\widehat{p}_{2,k}$', fontsize=20)
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('convergence_plot.png', dpi=300)
plt.show()

# Print final results
print("\n" + "="*60)
print("FINAL RESULTS")
print("="*60)
print(f"True parameters:     p1 = {p1_true:.4f}, p2 = {p2_true:.4f}")
print(f"Initial estimates:   p1 = {initial_estimates[0]:.4f}, p2 = {initial_estimates[1]:.4f}")
print(f"Final estimates:     p1 = {p1_estimates[-1]:.4f}, p2 = {p2_estimates[-1]:.4f}")
print(f"Final errors:        Δp1 = {abs(p1_estimates[-1] - p1_true):.4f}, Δp2 = {abs(p2_estimates[-1] - p2_true):.4f}")
print("="*60)
# Out:
# ============================================================
# FINAL RESULTS
# ============================================================
# True parameters:     p1 = 0.3000, p2 = 0.8000
# Initial estimates:   p1 = 0.5000, p2 = 0.5000
# Final estimates:     p1 = 0.2932, p2 = 0.8008
# Final errors:        Δp1 = 0.0068, Δp2 = 0.0008
# ============================================================

# %%
# Optional: Visualize policy evolution
if len(policies_history) >= 2:
    # Enable LaTeX rendering
    plt.rcParams['text.usetex'] = True
    plt.rcParams['font.family'] = 'serif'
    
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))
    
    # First policy
    heatmap1 = sns.heatmap(policies_history[0], ax=axes[0], cmap="coolwarm", 
                           annot=False, cbar=True, vmin=0, vmax=1)
    heatmap1.collections[0].colorbar.set_label(r'$\pi\big(n_1, n_2\big)$', fontsize=20)
    axes[0].set_xlabel(r'$n_2$', fontsize=20)
    axes[0].set_ylabel(r'$n_1$', fontsize=20)
    
    # Last policy
    heatmap2 = sns.heatmap(policies_history[-1], ax=axes[1], cmap="coolwarm", 
                           annot=False, cbar=True, vmin=0, vmax=1)
    heatmap2.collections[0].colorbar.set_label(r'$\pi\big(n_1, n_2\big)$', fontsize=20)
    axes[1].set_xlabel(r'$n_2$', fontsize=20)
    axes[1].set_ylabel(r'$n_1$', fontsize=20)
    
    plt.tight_layout()
    plt.savefig('policy_evolution.png', dpi=300)
    plt.show()
    
    print("\\nPolicy Interpretation:")
    print("- Red = more cores to Type 1 jobs (lower parallelizability)")
    print("- Blue = more cores to Type 2 jobs (higher parallelizability)")
# Out:
# \nPolicy Interpretation:
# - Red = more cores to Type 1 jobs (lower parallelizability)
# - Blue = more cores to Type 2 jobs (higher parallelizability)

# %%
# Speed-up sensitivity to core allocation changes - why lower p values are harder to estimate

def speed_up_1(p, n_cores):
    if n_cores >= 1:
        return 1/(1 - p*(1 - 1/n_cores))
    else:
        return n_cores

def speed_up_2(p, n_cores):
    if n_cores >= 1:
        return np.power(max(n_cores, 1), p)
    else:
        return n_cores

# Enable LaTeX rendering
plt.rcParams['text.usetex'] = True
plt.rcParams['font.family'] = 'serif'

fig, ax = plt.subplots(1, 1, figsize=(10, 6))

# Speed-up sensitivity to core allocation changes
# Include z < 1 so the shared processor-sharing branch s(z) = z is visible
cores_range = np.concatenate([np.linspace(0.1, 1, 10), np.arange(2, 21)])
p_values = [0.2, 0.4, 0.6, 0.8]

for p in p_values:
    speed_ups = [speed_up_2(p, c) for c in cores_range]
    ax.plot(cores_range, speed_ups, 'o-', label=f'p = {p}', linewidth=2, markersize=4)

ax.set_xlabel(r'$z$', fontsize=20)
ax.set_ylabel(r'$s(z;p)$', fontsize=20)
# ax.set_title('Speed-up vs Number of Cores for Different p Values', fontsize=14)
ax.legend(fontsize=20)
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('speed_up_sensitivity.png', dpi=300)
plt.show()

print("\n" + "="*60)
print("WHY LOWER p VALUES ARE HARDER TO ESTIMATE")
print("="*60)
print("• Lower p values (red/orange curves) show modest speed-up improvements")
print("• Higher p values (green curve) show dramatic speed-up gains")
print("• This makes it harder to distinguish different p₁ values from observed speed-ups")
print("• Type 2 jobs (p₂ = 0.9) respond dramatically to core allocation changes")
print("• Type 1 jobs (p₁ = 0.4) show modest improvements, making estimation harder")
print("="*60)
# Out:
# ============================================================
# WHY LOWER p VALUES ARE HARDER TO ESTIMATE
# ============================================================
# • Lower p values (red/orange curves) show modest speed-up improvements
# • Higher p values (green curve) show dramatic speed-up gains
# • This makes it harder to distinguish different p₁ values from observed speed-ups
# • Type 2 jobs (p₂ = 0.9) respond dramatically to core allocation changes
# • Type 1 jobs (p₁ = 0.4) show modest improvements, making estimation harder
# ============================================================
